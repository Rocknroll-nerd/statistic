# %% [markdown]
# <a href="https://colab.research.google.com/github/Rocknroll-nerd/statistic/blob/main/mltree_mlcourse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install graphviz libgraphviz-dev

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import pydotplus
from PIL import Image

clf = DecisionTreeClassifier(max_depth = 4, random_state = 17)
iris = load_iris()
clf.fit(iris.data, iris.target)
def tree_graph_to_png(tree, feature_names, png_file_to_save):
    tree_str = export_graphviz(tree, feature_names=feature_names, 
                                     filled=True, out_file=None)
    graph = pydotplus.graph_from_dot_data(tree_str)  
    graph.write_png(png_file_to_save)

tree_graph_to_png(clf, ['1','2','3','4'], png_file_to_save='aaa.png')

Image.open('aaa.png')
#answer=7
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1031x636 at 0x7F46D5023588>
